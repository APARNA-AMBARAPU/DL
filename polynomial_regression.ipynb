# %%
import numpy as np
import matplotlib.pyplot as plt
from keras.models import Sequential
from keras.layers import Dense
from keras.optimizers import Adam
# Out:
# Using TensorFlow backend.

# %%
np.random.seed(0)
points = 500
X = np.linspace(-3, 3, points)
y = np.sin(X) + np.random.uniform(-0.5, 0.5, points)

# %%
model = Sequential()
model.add(Dense(50, activation='sigmoid', input_dim=1))
model.add(Dense(30, activation='sigmoid'))
model.add(Dense(1))

# %%
adam = Adam(lr=0.01)
model.compile(loss='mse', optimizer=adam)
model.fit(X, y, epochs=50)
predictions = model.predict(X)
plt.scatter(X, y)
plt.plot(X, predictions, 'ro')
plt.show()
# Out:
# Epoch 1/50
# 500/500 [==============================] - 0s 187us/step - loss: 0.6104
# Epoch 2/50
# 500/500 [==============================] - 0s 39us/step - loss: 0.3006
# Epoch 3/50
# 500/500 [==============================] - 0s 44us/step - loss: 0.2303
# Epoch 4/50
# 500/500 [==============================] - 0s 47us/step - loss: 0.2392
# Epoch 5/50
# 500/500 [==============================] - 0s 73us/step - loss: 0.2178
# Epoch 6/50
# 500/500 [==============================] - 0s 46us/step - loss: 0.2116
# Epoch 7/50
# 500/500 [==============================] - 0s 41us/step - loss: 0.2052
# Epoch 8/50
# 500/500 [==============================] - 0s 39us/step - loss: 0.2007
# Epoch 9/50
# 500/500 [==============================] - 0s 39us/step - loss: 0.2000
# Epoch 10/50
# 500/500 [==============================] - 0s 39us/step - loss: 0.1851
# Epoch 11/50
# 500/500 [==============================] - 0s 39us/step - loss: 0.1730
# Epoch 12/50
# 500/500 [==============================] - 0s 48us/step - loss: 0.1709
# Epoch 13/50
# 500/500 [==============================] - 0s 44us/step - loss: 0.1671
# Epoch 14/50
# 500/500 [==============================] - 0s 44us/step - loss: 0.1524
# Epoch 15/50
# 500/500 [==============================] - 0s 44us/step - loss: 0.1390
# Epoch 16/50
# 500/500 [==============================] - 0s 43us/step - loss: 0.1378
# Epoch 17/50
# 500/500 [==============================] - 0s 42us/step - loss: 0.1299
# Epoch 18/50
# 500/500 [==============================] - 0s 56us/step - loss: 0.1255
# Epoch 19/50
# 500/500 [==============================] - 0s 45us/step - loss: 0.1222
# Epoch 20/50
# 500/500 [==============================] - 0s 44us/step - loss: 0.1176
# Epoch 21/50
# 500/500 [==============================] - 0s 43us/step - loss: 0.1188
# Epoch 22/50
# 500/500 [==============================] - 0s 43us/step - loss: 0.1153
# Epoch 23/50
# 500/500 [==============================] - 0s 42us/step - loss: 0.1142
# Epoch 24/50
# 500/500 [==============================] - 0s 44us/step - loss: 0.1175
# Epoch 25/50
# 500/500 [==============================] - 0s 40us/step - loss: 0.1125
# Epoch 26/50
# 500/500 [==============================] - 0s 41us/step - loss: 0.1132
# Epoch 27/50
# 500/500 [==============================] - 0s 46us/step - loss: 0.1174
# Epoch 28/50
# 500/500 [==============================] - 0s 42us/step - loss: 0.1112
# Epoch 29/50
# 500/500 [==============================] - 0s 44us/step - loss: 0.1089
# Epoch 30/50
# 500/500 [==============================] - 0s 46us/step - loss: 0.1150
# Epoch 31/50
# 500/500 [==============================] - 0s 38us/step - loss: 0.1122
# Epoch 32/50
# 500/500 [==============================] - 0s 45us/step - loss: 0.1154
# Epoch 33/50
# 500/500 [==============================] - 0s 42us/step - loss: 0.1114
# Epoch 34/50
# 500/500 [==============================] - 0s 47us/step - loss: 0.1075
# Epoch 35/50
# 500/500 [==============================] - 0s 42us/step - loss: 0.1109
# Epoch 36/50
# 500/500 [==============================] - 0s 44us/step - loss: 0.1105
# Epoch 37/50
# 500/500 [==============================] - 0s 40us/step - loss: 0.1161
# Epoch 38/50
# 500/500 [==============================] - 0s 43us/step - loss: 0.1087
# Epoch 39/50
# 500/500 [==============================] - 0s 38us/step - loss: 0.1048
# Epoch 40/50
# 500/500 [==============================] - 0s 45us/step - loss: 0.1076
# Epoch 41/50
# 500/500 [==============================] - 0s 40us/step - loss: 0.1112
# Epoch 42/50
# 500/500 [==============================] - 0s 47us/step - loss: 0.1051
# Epoch 43/50
# 500/500 [==============================] - 0s 46us/step - loss: 0.1122
# Epoch 44/50
# 500/500 [==============================] - 0s 47us/step - loss: 0.1038
# Epoch 45/50
# 500/500 [==============================] - 0s 45us/step - loss: 0.1070
# Epoch 46/50
# 500/500 [==============================] - 0s 42us/step - loss: 0.1024
# Epoch 47/50
# 500/500 [==============================] - 0s 39us/step - loss: 0.1020
# Epoch 48/50
# 500/500 [==============================] - 0s 40us/step - loss: 0.1118
# Epoch 49/50
# 500/500 [==============================] - 0s 38us/step - loss: 0.1151
# Epoch 50/50
# 500/500 [==============================] - 0s 39us/step - loss: 0.1086
